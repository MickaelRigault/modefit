# %%
# plot within the notebook
# %matplotlib inline
import warnings
# No annoying warnings
warnings.filterwarnings('ignore')
# Because we always need that
import numpy as np

# %% [markdown]
# # Fit Optinal emission lines with Minuit and the MCMC approach

# %%
import modefit

# %%
spectfile = "/Users/mrigault/Desktop/these/code_source/Data/SNIFS/SNF20080322-003/ulyss/1.0kpc/frefs_and_psfsubs/SNF20080322-003_frefs_and_psfsubs_weighted_mean_cma_stellar_free.fits"

# %%
fit = modefit.fit_spectrumlines(spectfile, zguess=0.0, modelName="Mains", fit=True)
# Out:
# STARTS MINUIT FIT
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = 217.357281511</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 481</td>
#                 <td title="Number of call in last migrad">NCALLS = 481</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 1.29729956616e-05</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 1e-05</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 1.0</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#OGztYSGEtS').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>HA</td>
#                 <td>19501.3</td>
#                 <td>1621.72</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>NII</td>
#                 <td>10937</td>
#                 <td>1413.13</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>OII1</td>
#                 <td>0</td>
#                 <td>60.3302</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>OII2</td>
#                 <td>12667.7</td>
#                 <td>3932.65</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>SII1</td>
#                 <td>13325.9</td>
#                 <td>1635.86</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>6</td>
#                 <td>SII2</td>
#                 <td>3760.12</td>
#                 <td>1487.42</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>7</td>
#                 <td>velocity</td>
#                 <td>71.7365</td>
#                 <td>14.4141</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td>-2000.0</td>
#                 <td>2000.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>8</td>
#                 <td>dispersion</td>
#                 <td>170.324</td>
#                 <td>12.5526</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td>50.0</td>
#                 <td>250.0</td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="OGztYSGEtS" style="display:none;">
#             <textarea rows="22" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & HA & 1.950e+04 & 1.622e+03 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 2 & NII & 1.094e+04 & 1.413e+03 &  &  &  &  & \\
# \hline
# 3 & OII1 & 0.000e+00 & 6.033e+01 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 4 & OII2 & 1.267e+04 & 3.933e+03 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 5 & SII1 & 1.333e+04 & 1.636e+03 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 6 & SII2 & 3.760e+03 & 1.487e+03 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 7 & velocity & 7.174e+01 & 1.441e+01 &  &  & -2.000e+03 & 2.000e+03 & \\
# \hline
# 8 & dispersion & 1.703e+02 & 1.255e+01 &  &  & 5.000e+01 & 2.500e+02 & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# STARTS MINUIT FIT
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = 194.000085902</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 209</td>
#                 <td title="Number of call in last migrad">NCALLS = 209</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 0.000107282202572</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 1e-05</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 1.0</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#adFLxDyifC').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>HA</td>
#                 <td>19509.3</td>
#                 <td>1716.93</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>NII</td>
#                 <td>10942.4</td>
#                 <td>1496.15</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>OII1</td>
#                 <td>0.0481097</td>
#                 <td>68.2034</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>OII2</td>
#                 <td>12653.9</td>
#                 <td>4163.79</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>SII1</td>
#                 <td>13334.5</td>
#                 <td>1732.01</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>6</td>
#                 <td>SII2</td>
#                 <td>3763.25</td>
#                 <td>1574.9</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>7</td>
#                 <td>velocity</td>
#                 <td>71.7268</td>
#                 <td>15.2613</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td>-2000.0</td>
#                 <td>2000.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>8</td>
#                 <td>dispersion</td>
#                 <td>170.427</td>
#                 <td>13.2904</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td>50.0</td>
#                 <td>250.0</td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="adFLxDyifC" style="display:none;">
#             <textarea rows="22" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & HA & 1.951e+04 & 1.717e+03 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 2 & NII & 1.094e+04 & 1.496e+03 &  &  &  &  & \\
# \hline
# 3 & OII1 & 4.811e-02 & 6.820e+01 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 4 & OII2 & 1.265e+04 & 4.164e+03 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 5 & SII1 & 1.333e+04 & 1.732e+03 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 6 & SII2 & 3.763e+03 & 1.575e+03 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 7 & velocity & 7.173e+01 & 1.526e+01 &  &  & -2.000e+03 & 2.000e+03 & \\
# \hline
# 8 & dispersion & 1.704e+02 & 1.329e+01 &  &  & 5.000e+01 & 2.500e+02 & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>

# %%
fit.show()
# Out:
# {'ax': <matplotlib.axes._axes.Axes at 0x108a11e50>,
#  'figure': <matplotlib.figure.Figure at 0x108a11890>,
#  'plot': [([<matplotlib.lines.Line2D at 0x108d299d0>],
#    <matplotlib.collections.PolyCollection at 0x108bcfad0>),
#   [<matplotlib.lines.Line2D at 0x108bc4b10>]],
#  'prop': {}}

# %% [markdown]
# ## We can also use the MCMC approach

# %%
fit.run_mcmc(2000)

# %% [markdown]
# You need to visualize the walkers to identify the burn-in value

# %%
fit.show_mcmcwalkers()

# %% [markdown]
# Here it look like 1000 because of the OII1 line

# %%
fit.set_mcmc_burnin(1000)
fit.show_mcmc_corner()
