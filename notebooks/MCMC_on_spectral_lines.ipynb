# %%
# plot within the notebook
# %matplotlib inline
import warnings
# No annoying warnings
warnings.filterwarnings('ignore')
# Because we always need that
import numpy as np

# %%
import snakeviz
# %load_ext snakeviz

# %%
import matplotlib.pyplot as mpl

# %% [markdown]
# # Fit Optinal emission lines with Minuit and the MCMC approach

# %%
import modefit

# %%
spectfile = "/Users/mrigault/Desktop/these/code_source/Data/SNIFS/PTF13ajv/ulyss/1.0kpc/frefs/PTF13ajv_frefs_weighted_mean_cma_stellar_free.fits"

# %%
time fit = modefit.fit_spectrumlines(spectfile, zguess=0.0, modelName="Mains", fit=True)
# Out:
# STARTS MINUIT FIT
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = 116.405750436</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 427</td>
#                 <td title="Number of call in last migrad">NCALLS = 427</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 6.02619586924e-05</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 1e-05</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 1.0</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#FNSFTUslzF').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>HA</td>
#                 <td>343.101</td>
#                 <td>79.982</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>NII</td>
#                 <td>142.377</td>
#                 <td>67.0328</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>OII1</td>
#                 <td>0.00795184</td>
#                 <td>57.8675</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>OII2</td>
#                 <td>343.524</td>
#                 <td>233.125</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>SII1</td>
#                 <td>28.1822</td>
#                 <td>54.7529</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>6</td>
#                 <td>SII2</td>
#                 <td>1.81438e-07</td>
#                 <td>18.8525</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>7</td>
#                 <td>velocity</td>
#                 <td>-14.3072</td>
#                 <td>32.2461</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td>-2000.0</td>
#                 <td>2000.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>8</td>
#                 <td>dispersion</td>
#                 <td>123.062</td>
#                 <td>27.3564</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td>50.0</td>
#                 <td>250.0</td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="FNSFTUslzF" style="display:none;">
#             <textarea rows="22" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & HA & 3.431e+02 & 7.998e+01 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 2 & NII & 1.424e+02 & 6.703e+01 &  &  &  &  & \\
# \hline
# 3 & OII1 & 7.952e-03 & 5.787e+01 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 4 & OII2 & 3.435e+02 & 2.331e+02 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 5 & SII1 & 2.818e+01 & 5.475e+01 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 6 & SII2 & 1.814e-07 & 1.885e+01 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 7 & velocity & -1.431e+01 & 3.225e+01 &  &  & -2.000e+03 & 2.000e+03 & \\
# \hline
# 8 & dispersion & 1.231e+02 & 2.736e+01 &  &  & 5.000e+01 & 2.500e+02 & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# STARTS MINUIT FIT
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = 199.999912215</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 247</td>
#                 <td title="Number of call in last migrad">NCALLS = 247</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 1.39763733261e-05</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 1e-05</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 1.0</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#rrFcYWaewG').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>HA</td>
#                 <td>342.809</td>
#                 <td>60.9887</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>NII</td>
#                 <td>142.403</td>
#                 <td>51.1333</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>OII1</td>
#                 <td>1.13174e-06</td>
#                 <td>43.1775</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>OII2</td>
#                 <td>344.731</td>
#                 <td>177.921</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>SII1</td>
#                 <td>28.3971</td>
#                 <td>34.6564</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>6</td>
#                 <td>SII2</td>
#                 <td>8.71887e-05</td>
#                 <td>14.144</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>7</td>
#                 <td>velocity</td>
#                 <td>-14.1281</td>
#                 <td>24.6166</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td>-2000.0</td>
#                 <td>2000.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>8</td>
#                 <td>dispersion</td>
#                 <td>123.068</td>
#                 <td>20.9926</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td>50.0</td>
#                 <td>250.0</td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="rrFcYWaewG" style="display:none;">
#             <textarea rows="22" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & HA & 3.428e+02 & 6.099e+01 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 2 & NII & 1.424e+02 & 5.113e+01 &  &  &  &  & \\
# \hline
# 3 & OII1 & 1.132e-06 & 4.318e+01 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 4 & OII2 & 3.447e+02 & 1.779e+02 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 5 & SII1 & 2.840e+01 & 3.466e+01 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 6 & SII2 & 8.719e-05 & 1.414e+01 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 7 & velocity & -1.413e+01 & 2.462e+01 &  &  & -2.000e+03 & 2.000e+03 & \\
# \hline
# 8 & dispersion & 1.231e+02 & 2.099e+01 &  &  & 5.000e+01 & 2.500e+02 & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# CPU times: user 1.38 s, sys: 53.5 ms, total: 1.43 s
# Wall time: 1.51 s

# %% [markdown]
# # MCMC

# %%
fit.run_mcmc(5000)

# %% [markdown]
# You need to visualize the walkers to identify the burn-in value

# %%
fit.show_mcmcwalkers()

# %% [markdown]
# Here it look like 700 because of the OII1 line

# %%
fit.set_mcmc_burnin(1000)
fit.show_mcmc_corner()
